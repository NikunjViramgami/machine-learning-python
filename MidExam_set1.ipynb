# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
movie=pd.read_csv("Movie-data.csv")
movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#Q1 Load data set using pandas function and print top 10 record
movie.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
#Q2 Which movie earns the most and least profit?
modf=movie["Revenue (Millions)"]
modf
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
MaxRev=max(modf)
MaxRev
# Out:
# 936.63

# %%
MinRev=min(modf)
MinRev
# Out:
# 0.0

# %%
#Q3 Print movies which have a value of '0' in their budget or revenue.
budget=movie[movie["Revenue (Millions)"]==0]
budget
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
#Q4 calculate the total Profits made by all movies in year which it released.
y=movie["Year"]
y
# Out:
# 0      2014
# 1      2012
# 2      2016
# 3      2016
# 4      2016
#        ...
# 995    2015
# 996    2007
# 997    2008
# 998    2014
# 999    2016
# Name: Year, Length: 1000, dtype: int64

# %%
#find unique value
uyear=y.unique()
uyear
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013],
#       dtype=int64)

# %%
uyear.sort()
uyear
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
uyear.sum()
# Out:
# 22121

# %%
r2007=movie[movie["Year"]==2007]
r2007
# Out:
#      Rank                                              Title  \
# 39     40                                          5- 25- 77
# 75     76           Pirates of the Caribbean: At World's End
# 136   137                             No Country for Old Men
# 148   149                                           Superbad
# 155   156                       Aliens vs Predator - Requiem
# 159   160                                           Hot Fuzz
# 197   198                                      Into the Wild
# 212   213                                       Transformers
# 277   278                                             Zodiac
# 282   283                                        Death Proof
# 299   300                                There Will Be Blood
# 314   315          Harry Potter and the Order of the Phoenix
# 344   345                                       Spider-Man 3
# 346   347                                           Stardust
# ...

# %%
rev2007=r2007["Revenue (Millions)"]
rev2007
# Out:
# 39        NaN
# 75     309.40
# 136     74.27
# 148    121.46
# 155     41.80
# 159     23.62
# 197     18.35
# 212    318.76
# 277     33.05
# 282       NaN
# 299     40.22
# 314    292.00
# 344    336.53
# 346     38.35
# 417     50.92
# 421      0.04
# 427    227.14
# 470    130.13
# 486    118.82
# 489    206.44
# 495    256.39
# 511     46.98
# 543     53.68
# 567    143.49
# 571    127.71
# 585    115.80
# 588      3.68
# 613      3.90
# 635    148.73
# 650     52.88
# 658     17.11
# 662     20.30
# 675     25.59
# 698    134.52
# 700      1.29
# 714     36.77
# 750     39.00
# 760     31.66
# 782     28.48
# 802     82.16
# 804     71.98
# 828     25.03
# 857     36.58
# 875     28.64
# 895       NaN
# 907    117.14
# 912     82.23
# 917       NaN
# 919     70.08
# 971     80.05
# 982     24.34
# 991      1.20
# 996     17.54
# Name: Revenue (Millions), dtype: float64

# %%
rev2007.sum()
# Out:
# 4306.2300000000005

# %%
revlist=[]
revdic={}
for year in uyear:
    ryear=movie[movie["Year"]==year]
    revofyear=ryear["Revenue (Millions)"]
    print(f"Total Revenue of the year{year} is {revofyear.sum()} in Millions")
    revlist.append(revofyear.sum())
    revdic[year]=revofyear.sum()
# Out:
# Total Revenue of the year2006 is 3624.4599999999996 in Millions
# Total Revenue of the year2007 is 4306.2300000000005 in Millions
# Total Revenue of the year2008 is 5053.220000000001 in Millions
# Total Revenue of the year2009 is 5292.26 in Millions
# Total Revenue of the year2010 is 5989.650000000001 in Millions
# Total Revenue of the year2011 is 5431.96 in Millions
# Total Revenue of the year2012 is 6910.289999999999 in Millions
# Total Revenue of the year2013 is 7666.72 in Millions
# Total Revenue of the year2014 is 7997.4 in Millions
# Total Revenue of the year2015 is 8854.119999999999 in Millions
# Total Revenue of the year2016 is 11211.65 in Millions

# %%
#Q5 Draw line chart for run time of movie. 
x=movie["Title"]
y=movie["Runtime (Minutes)"]
plt.plot(x,y,"r:",marker="^")
plt.show()

# %%
#Q6 In which year we had the most movies making profits?
revlist
# Out:
# [3624.4599999999996,
#  4306.2300000000005,
#  5053.220000000001,
#  5292.26,
#  5989.650000000001,
#  5431.96,
#  6910.289999999999,
#  7666.72,
#  7997.4,
#  8854.119999999999,
#  11211.65]

# %%
maxrev=revlist[0]
for revnue in revlist:
    if maxrev<revnue:
        maxrev=revnue
print(maxrev)
# Out:
# 11211.65

# %%
#Q7 Print the size and shape of the data set.
movie.size
# Out:
# 12000

# %%
movie.shape
# Out:
# (1000, 12)

# %%
# Q8 Remove the duplicate record from the dataset. 
movie.duplicated().value_counts()
# Out:
# False    1000
# dtype: int64

# %%
#Q9 Count the null values in the data set and fill with the average value. 
movie.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
rmean=movie.mean()
rmean
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24736\1934486029.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rmean=movie.mean()
# Rank                     500.500000
# Year                    2012.783000
# Runtime (Minutes)        113.172000
# Rating                     6.723200
# Votes                 169808.255000
# Revenue (Millions)        82.956376
# Metascore                 58.985043
# dtype: float64

# %%
rmean["Revenue (Millions)"]
# Out:
# 82.95637614678897

# %%
rev=movie["Revenue (Millions)"]
rev.mean()
# Out:
# 82.95637614678897

# %%
rev.fillna(rev.mean(),inplace=True)

# %%
rev
# Out:
# 0      333.130000
# 1      126.460000
# 2      138.120000
# 3      270.320000
# 4      325.020000
#           ...
# 995     82.956376
# 996     17.540000
# 997     58.010000
# 998     82.956376
# 999     19.640000
# Name: Revenue (Millions), Length: 1000, dtype: float64
