# %%
import pandas as pd

# %%
a1=pd.read_csv('Movie-Data.csv',index_col='Title')
a1
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
#column vise find
subset=a1['Genre']
subset
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
type(subset)
# Out:
# pandas.core.series.Series

# %%
subset=a1[['Genre','Director']]
subset
# Out:
#                         Genre              Director
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
#row wise find row
s1=a1.iloc[14:25]
s1
# Out:
#     Rank                         Title                       Genre  \
# 14    15                      Colossal         Action,Comedy,Drama
# 15    16       The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                 Hacksaw Ridge     Biography,Drama,History
# 17    18                  Jason Bourne             Action,Thriller
# 18    19                          Lion             Biography,Drama
# 19    20                       Arrival        Drama,Mystery,Sci-Fi
# 20    21                          Gold    Adventure,Drama,Thriller
# 21    22         Manchester by the Sea                       Drama
# 22    23                Hounds of Love          Crime,Drama,Horror
# 23    24                        Trolls  Animation,Adventure,Comedy
# 24    25  Independence Day: Resurgence     Action,Adventure,Sci-Fi
#
#                                           Description          Director  \
# 14  Gloria is an out-of-work party girl forced to ...   Nacho Vigalondo
# ...

# %%
#iloc or another way to find row
#loc is only use string so index is 0124 then not in use loc
s2=a1.loc['Trolls']
s2
# Out:
# Rank                                                                 24
# Genre                                        Animation,Adventure,Comedy
# Description           After the Bergens invade Troll Village, Poppy,...
# Director                                                     Walt Dohrn
# Actors                Anna Kendrick, Justin Timberlake,Zooey Deschan...
# Year                                                             2016.0
# Runtime (Minutes)                                                    92
# Rating                                                              6.5
# Votes                                                             38552
# Revenue (Millions)                                               153.69
# Metascore                                                          56.0
# Name: Trolls, dtype: object

# %%
s3=a1.loc['Prometheus']
s3
# Out:
# Rank                                                                  2
# Genre                                          Adventure,Mystery,Sci-Fi
# Description           Following clues to the origin of mankind, a te...
# Director                                                   Ridley Scott
# Actors                Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Year                                                             2012.0
# Runtime (Minutes)                                                   124
# Rating                                                              7.0
# Votes                                                            485820
# Revenue (Millions)                                               126.46
# Metascore                                                          65.0
# Name: Prometheus, dtype: object

# %%
s4=a1.iloc[700:801]
s4
# Out:
#                              Rank                       Genre  \
# Title
# Funny Games                   701          Crime,Drama,Horror
# Ted                           702              Comedy,Fantasy
# RED                           703         Action,Comedy,Crime
# Australia                     704     Adventure,Drama,Romance
# Faster                        705          Action,Crime,Drama
# ...                           ...                         ...
# Rescue Dawn                   797   Adventure,Biography,Drama
# Despicable Me 2               798  Animation,Adventure,Comedy
# A Walk Among the Tombstones   799         Crime,Drama,Mystery
# The World's End               800        Action,Comedy,Sci-Fi
# Yoga Hosers                   801       Comedy,Fantasy,Horror
#
#                                                                    Description  \
# Title
# Funny Games                  Two psychopathic young men take a family hosta...
# ...

# %%
s4=a1.iloc[797:801]
s4
# Out:
#      Rank                        Title                       Genre  \
# 797   798              Despicable Me 2  Animation,Adventure,Comedy
# 798   799  A Walk Among the Tombstones         Crime,Drama,Mystery
# 799   800              The World's End        Action,Comedy,Sci-Fi
# 800   801                  Yoga Hosers       Comedy,Fantasy,Horror
#
#                                            Description       Director  \
# 797  When Gru, the world's most super-bad turned su...  Pierre Coffin
# 798  Private investigator Matthew Scudder is hired ...    Scott Frank
# 799  Five friends who reunite in an attempt to top ...   Edgar Wright
# 800  Two teenage yoga enthusiasts team up with a le...    Kevin Smith
#
#                                                 Actors    Year  \
# 797  Steve Carell, Kristen Wiig, Benjamin Bratt, Mi...  2013.0
# 798  Liam Neeson, Dan Stevens, David Harbour, Boyd ...  2014.0
# 799  Simon Pegg, Nick Frost, Martin Freeman, Rosamu...  2013.0
# ...

# %%
#find 2012 year records movie
data=a1[(a1['Year']>=2012)]
data
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Suicide Squad               5  Action,Adventure,Fantasy
# La La Land                  7        Comedy,Drama,Music
# Mindhorn                    8                    Comedy
# ...                       ...                       ...
# Endless Love              988             Drama,Romance
# Selma                     990   Biography,Drama,History
# Project X                 995                    Comedy
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data=a1[(a1['Director']=='Ridley Scott')]
data
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# ...

# %%
#find 2012 to 2018 moviews
data=a1[(a1['Year']>=2012) & (a1['Year']<=2018)]
data
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Suicide Squad               5  Action,Adventure,Fantasy
# La La Land                  7        Comedy,Drama,Music
# Mindhorn                    8                    Comedy
# ...                       ...                       ...
# Endless Love              988             Drama,Romance
# Selma                     990   Biography,Drama,History
# Project X                 995                    Comedy
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data=a1[(a1['Year']>=2012) & (a1['Year']<=2018)].head(3)
data
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Suicide Squad            A secret government agency recruits some of th...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
# Suicide Squad              David Ayer
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# ...

# %%
data=a1[(a1['Year']>=2012) & (a1['Year']<=2018) & (a1['Rating']>=8)]
data
# Out:
#                                             Rank                       Genre  \
# Title
# Guardians of the Galaxy                        1     Action,Adventure,Sci-Fi
# La La Land                                     7          Comedy,Drama,Music
# Hacksaw Ridge                                 17     Biography,Drama,History
# Lion                                          19             Biography,Drama
# Arrival                                       20        Drama,Mystery,Sci-Fi
# Bahubali: The Beginning                       27      Action,Adventure,Drama
# Deadpool                                      34     Action,Adventure,Comedy
# Interstellar                                  37      Adventure,Drama,Sci-Fi
# Star Wars: Episode VII - The Force Awakens    51    Action,Adventure,Fantasy
# Mad Max: Fury Road                            68     Action,Adventure,Sci-Fi
# Zootopia                                      75  Animation,Adventure,Comedy
# ...

# %%
#Or operator
data=a1[(a1['Director']=='James Gunn') | (a1['Director']=='Mel Gibson')]
data
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# Hacksaw Ridge              17  Biography,Drama,History
# Apocalypto                233   Action,Adventure,Drama
# Slither                   909     Comedy,Horror,Sci-Fi
# Super                     938             Comedy,Drama
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Hacksaw Ridge            WWII American Army Medic Desmond T. Doss, who ...
# Apocalypto               As the Mayan kingdom faces its decline, the ru...
# Slither                  A small town is taken over by an alien plague,...
# Super                    After his wife falls under the influence of a ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
# Hacksaw Ridge            Mel Gibson
# Apocalypto               Mel Gibson
# ...

# %%
data=a1[(a1['Year']>2005) & (a1['Year']<2010) & (a1['Rating']>8) & (a1['Revenue (Millions)']<a1['Revenue (Millions)'].quantile(0.25))]
data
# Out:
#                      Rank           Genre  \
# Title
# 3 Idiots              431    Comedy,Drama
# The Lives of Others   477  Drama,Thriller
#
#                                                            Description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
#
#                                              Director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
#
#                                                                 Actors  \
# Title
# 3 Idiots               Aamir Khan, Madhavan, Mona Singh, Sharman Joshi
# The Lives of Others  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...
#
#                        Year  Runtime (Minutes)  Rating   Votes  \
# Title
# 3 Idiots             2009.0                170     8.4  238789
# The Lives of Others  2006.0                137     8.5  278103
#
# ...

# %%
#25% revenue find
a1['Revenue (Millions)'].quantile(0.25)
# Out:
# 13.27
