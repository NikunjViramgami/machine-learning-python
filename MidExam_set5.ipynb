# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
diamond=pd.read_csv("diamonds.csv")
diamond
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
#Q1
diamond.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#Q2 Draw the bar chart of costliest and cheapest diamonds . 
data=diamond["price"]
data
maxprice=max(data)
minprice=min(data)
print(maxprice,minprice)
# Out:
# 2777 326

# %%
sort=diamond.sort_values("price")
sort

# Select the costliest and cheapest diamonds
top=sort.head(1)
bottom=sort.tail(1)

# Concatenate the top and bottom diamonds into a single DataFrame
merge=pd.concat([top,bottom])

# Create a bar chart of the selected diamonds
merge.plot(x="carat", y="price", kind="bar", figsize=(8,6), grid=True)

# %%
#Q3 Draw the chart for Price vs Carat of Diamonds. 
x=diamond["price"]
y=diamond["carat"]
plt.plot(x,y,"y:")
plt.show()

# %%
#Q4 Print the record where either of dimension (x,y,z) is Zero

dim=diamond[(diamond["x"]==0) | (diamond["y"]==0) | (diamond["z"]==0)]
dim
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
#Q5 Create a new data frame by multiplying x,y,z. 
diamond["Area"]=diamond['x']*diamond['y']*diamond['z']

# %%
diamond
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
#            Area
# 0     38.202030
# 1     34.505856
# 2     38.076885
# 3     46.724580
# ...

# %%
#Q6 Drop all the dimension.(X,Y,Z).
drop=diamond.drop(["x","y","z"],axis=1)
drop
# Out:
#      carat      cut color clarity  depth  table  price        Area
# 0     0.23    Ideal     E     SI2   61.5   55.0    326   38.202030
# 1     0.21  Premium     E     SI1   59.8   61.0    326   34.505856
# 2     0.23     Good     E     VS1   56.9   65.0    327   38.076885
# 3     0.29  Premium     I     VS2   62.4   58.0    334   46.724580
# 4     0.31     Good     J     SI2   63.3   58.0    335   51.917250
# ..     ...      ...   ...     ...    ...    ...    ...         ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  113.586936
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  113.004234
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  113.261472
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  116.046216
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  115.568640
#
# [199 rows x 8 columns]

# %%
#Q7 Print all the Statistical information of the data frame. 
diamond.describe()
# Out:
#             carat       depth       table        price           x  \
# count  199.000000  199.000000  199.000000   199.000000  199.000000
# mean     0.524020   61.629146   57.719598  1712.035176    5.047588
# std      0.237057    1.613471    2.355365  1166.046417    0.834121
# min      0.200000   55.100000   53.000000   326.000000    3.790000
# 25%      0.290000   60.800000   56.000000   404.000000    4.225000
# 50%      0.700000   61.700000   57.000000  2760.000000    5.560000
# 75%      0.720000   62.600000   59.000000  2768.000000    5.790000
# max      1.170000   66.300000   69.000000  2777.000000    6.830000
#
#                 y           z        Area
# count  199.000000  199.000000  199.000000
# mean     5.055075    3.112462   85.688806
# std      0.823563    0.512692   38.459730
# min      3.750000    2.270000   32.262375
# 25%      4.250000    2.615000   47.841691
# 50%      5.580000    3.380000  109.004544
# 75%      5.780000    3.560000  118.094107
# ...

# %%
#Q8  Remove all the duplicate values from the data frame
duplicate=diamond.append(diamond)
duplicate
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22164\2086606313.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   duplicate=diamond.append(diamond)
#      carat      cut color clarity  depth  table  price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# ...

# %%
duplicate.drop_duplicates()
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
#            Area
# 0     38.202030
# 1     34.505856
# 2     38.076885
# 3     46.724580
# ...

# %%
#Q9 Count the null values in the database and replace with mean value.
diamond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# Area       0
# dtype: int64
