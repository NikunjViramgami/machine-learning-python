# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
cars=pd.read_csv("cars.csv")
cars
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
#Q1
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1           1   2899       ford       se  2011  clean vehicle   190552
# 2           2   5350      dodge      mpv  2018  clean vehicle    39590
# 3           3  25000       ford     door  2014  clean vehicle    64146
# 4           4  27700  chevrolet     1500  2018  clean vehicle     6654
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
#Q2 Print the size and shape of the data frame.
cars.size
# Out:
# 2301

# %%
cars.shape
# Out:
# (177, 13)

# %%
#Q3 Find the mean price for each brand using the pandas function
c=cars["brand"]
c
# Out:
# 0         toyota
# 1           ford
# 2          dodge
# 3           ford
# 4      chevrolet
#          ...
# 172        dodge
# 173         ford
# 174    chevrolet
# 175         ford
# 176         ford
# Name: brand, Length: 177, dtype: object

# %%
for i in c:
    print(i)
# Out:
# toyota
# ford
# dodge
# ford
# chevrolet
# dodge
# chevrolet
# gmc
# chevrolet
# ford
# dodge
# gmc
# chevrolet
# chrysler
# ford
# gmc
# kia
# buick
# ford
# ford
# gmc
# kia
# chevrolet
# ford
# ford
# gmc
# kia
# buick
# ford
# ford
# gmc
# infiniti
# chevrolet
# ford
# ford
# gmc
# mercedes-benz
# chevrolet
# ford
# ford
# gmc
# mercedes-benz
# chevrolet
# ford
# ford
# gmc
# jeep
# chevrolet
# dodge
# ford
# gmc
# jeep
# buick
# ford
# chrysler
# gmc
# jeep
# buick
# chrysler
# chrysler
# gmc
# jeep
# chevrolet
# ford
# chrysler
# gmc
# jeep
# chevrolet
# ford
# chrysler
# gmc
# jeep
# bmw
# ford
# chrysler
# gmc
# jeep
# buick
# ford
# chrysler
# gmc
# jeep
# chevrolet
# ford
# ford
# gmc
# jeep
# chevrolet
# ford
# ford
# ford
# chrysler
# bmw
# ford
# dodge
# bmw
# ford
# ford
# chevrolet
# ford
# ford
# cadillac
# ford
# ford
# cadillac
# ford
# ford
# chevrolet
# ford
# dodge
# cadillac
# ford
# ford
# chevrolet
# ford
# dodge
# chevrolet
# ford
# chrysler
# chevrolet
# ...

# %%
#Q3 find the mean value of price for each brand
cars.groupby("brand").price.mean()
# Out:
# brand
# bmw              37566.666667
# buick            20017.500000
# cadillac         28851.333333
# chevrolet        24665.266667
# chrysler         18332.307692
# dodge             8581.600000
# ford             14645.327586
# gmc              12711.176471
# infiniti         18500.000000
# jeep             17955.555556
# kia              11333.333333
# mercedes-benz    16600.000000
# toyota            6300.000000
# Name: price, dtype: float64

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
#Q4  Count the car having Black color.
name=cars[cars["color"]=="black"]
name
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 12           12  31900  chevrolet      1500  2018  clean vehicle    22909
# 14           14  20700       ford      door  2013  clean vehicle   100757
# 21           21   7300        kia     forte  2018  clean vehicle    38823
# 22           22  15000  chevrolet      door  2015  clean vehicle    61578
# 35           35  11900        gmc      door  2017  clean vehicle    27965
# 44           44  55000       ford       srw  2017  clean vehicle    15273
# 45           45  12520        gmc      door  2017  clean vehicle    28972
# 49           49  54000       ford       srw  2017  clean vehicle    26241
# 62           62  17800  chevrolet      door  2017  clean vehicle    52435
# ...

# %%
#count the value
len(name)
# Out:
# 43

# %%
#Q5 Find which Brand have maximum car in year 2017
max=cars[cars["year"]==2017]
max
# Out:
#      Unnamed: 0  price      brand  model  year   title_status  mileage  \
# 7             7  13350        gmc   door  2017  clean vehicle    23525
# 9             9   5250       ford    mpv  2017  clean vehicle    63418
# 11           11  12920        gmc    mpv  2017  clean vehicle    39650
# 13           13   5430   chrysler  wagon  2017  clean vehicle   138650
# 15           15  12710        gmc   door  2017  clean vehicle    25747
# ..          ...    ...        ...    ...   ...            ...      ...
# 137         137  19500   chrysler    300  2017  clean vehicle    31311
# 138         138  32012  chevrolet   1500  2017  clean vehicle    46091
# 142         142  31802  chevrolet   2500  2017  clean vehicle    19845
# 145         145  28402  chevrolet   1500  2017  clean vehicle    31234
# 175         175  15110       ford   door  2017  clean vehicle    42289
#
#       color                  vin        lot       state country      condition
# ...

# %%
a=max["brand"]
a
# Out:
# 7            gmc
# 9           ford
# 11           gmc
# 13      chrysler
# 15           gmc
#          ...
# 137     chrysler
# 138    chevrolet
# 142    chevrolet
# 145    chevrolet
# 175         ford
# Name: brand, Length: 83, dtype: object

# %%
b=a.max()
b
# Out:
# 'gmc'

# %%
#Q6  Create a line chart which shows proportion for each car brand.
car = cars['brand'].unique()
num_car = []
for brand in car:
    num = len(cars[cars['brand']==brand])
    num_car.append(num)
print(num_car)
fig = plt.figure(figsize =(10, 7))
plt.pie(num_car, labels = car)
 
# show plot
plt.show()
# Out:
# [1, 58, 25, 30, 17, 13, 3, 6, 1, 2, 9, 6, 6]

# %%
#Q7
cars.describe

# %%
#Q8
cars.drop_duplicates()

# %%
#Q9
cars.isnull().sum()
