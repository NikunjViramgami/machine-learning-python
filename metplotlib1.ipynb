# %%
import matplotlib.pyplot as plt

# %%
#use for x y direction graph
x=[1,2,3,4]
y=[10,20,30,40] #y=x*10
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'b--')
plt.show()

# %%
plt.plot(x,y,'g:',marker='*') #g for color code green we have 
plt.show()

# %%
#we have use diff diff mark like.,+
plt.plot(x,y,'g:',marker='.')
plt.show()

# %%
import numpy as np

# %%
t=np.arange(0.,5.,0.2)
#0.2 distance for lines
#t for x direct t for y direction 
plt.plot(t,t,'k--',t,t**2,'ro',t,t**3,'g^')
#bs=bluesqare and green triangles k==black
plt.show()

# %%
x=[1,2,3,4,]
y=[10,10,20,30]
plt.plot(x,y,color='green',marker='^',linestyle='dashed',mec='r',mfc='b',linewidth=3,markersize=10)
#mec=marker edge color or mfc=marker face color

# %%
x=[1,3,4,4]
y=[20,20,20,20]
plt.plot(x,y,'b--')
plt.show()

# %%
x=[1,1,1]
y=[1,2,3]
a=[1,2,3]
b=[1,1,1]
e=[3,3,3]
f=[1,2,3]
g=[1,2,3]
h=[3,3,3]
plt.plot(x,y,'g:',marker='^')
plt.plot(a,b,'r:',marker='^')
plt.plot(e,f,'b:',marker='^')
plt.plot(g,h,'y:',marker='^')
plt.show()

# %%
a=[1,1,1,1,1,1,2,3,4,5,5,5,5,5,5,5,4,3,2,1,]
b=[1,2,3,4,5,5,5,5,5,5,5,4,3,2,1,1,1,1,1,1]
x=[2,2,2,2,2,2,2.5,3,3.5,4,4,4,4,4,4,4,3.5,3,2.5,2]
y=[2,2.5,3,3.5,4,4,4,4,4,4,4,3.5,3,2.5,2,2,2,2,2,2]
c=[1.5,1.5,1.5,1.5,1.5,2.5,3.5,4.5,4.5,4.5,4.5,4.5,4.5,3.5,2.5,1.5]
d=[1.5,2.5,3.5,4.5,4.5,4.5,4.5,4.5,4.5,3.5,2.5,1.5,1.5,1.5,1.5,1.5]
p=[2.5,2.5,2.5,3.5,3.5,3.5,3.5,2.5]
q=[2.5,3.5,3.5,3.5,3.5,2.5,2.5,2.5]
r=[3]
s=[3]
plt.plot(a,b,'g:',marker='^')
plt.plot(x,y,'r:',marker='^')
plt.plot(c,d,'y:',marker='^')
plt.plot(p,q,'k:',marker='^')
plt.plot(r,s,'k:',marker='^')
plt.show()

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x=[1,1.5,1,1,1.5,1.5,1,1.250,1.5,1,1.5,1.250,1]
y=[1,2,3,1,1,3,3,1,3,2,1,3,1]
plt.plot(x,y,"g:",marker="^")
plt.show()

# %%
res={'name':['Raj','Om','Kishan'],'python':[40,50,60],'java':[80,60,70],'cvv':[80,30,40],'rollno':[1,2,3]}

data=pd.DataFrame(res)
data
# Out:
#      name  python  java  cvv  rollno
# 0     Raj      40    80   80       1
# 1      Om      50    60   30       2
# 2  Kishan      60    70   40       3

# %%
data['total']=data['python']+data['java']+data['cvv']
data
# Out:
#      name  python  java  cvv  rollno  total
# 0     Raj      40    80   80       1    200
# 1      Om      50    60   30       2    140
# 2  Kishan      60    70   40       3    170

# %%
x=data['total'].values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
